# %%
import csv #to read in network data

import networkx as nx 
import pandas as pd #data analysis library
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#load the df
#via: http://www.thebaseballcube.com/mlb/people/coaches/byTeam.asp?T=20#
ym = pd.read_csv("https://raw.githubusercontent.com/pbarston/Yankees_Coaching_Tree/main/Yankees%20Managers%20Historical.csv",
           header = 0,
           index_col = 0,
           na_values = "---",
            sep = ",")
ym.head()
# Out:
#       Stats  Roster      Team Pages Field Manager     Bench Coach  \
# Year
# 2021  Stats  Roster  Franchise Page   Aaron Boone  Carlos Mendoza
# 2020  Stats  Roster  Franchise Page   Aaron Boone  Carlos Mendoza
# 2019  Stats  Roster  Franchise Page   Aaron Boone       Josh Bard
# 2018  Stats  Roster  Franchise Page   Aaron Boone       Josh Bard
# 2017  Stats  Roster  Franchise Page   Joe Girardi     Rob Thomson
#
#                       Hitting Coach    Pitching Coach First Base Coach  \
# Year
# 2021  P.J. Pilittere, Marcus Thames        Matt Blake   Reggie Willits
# 2020  P.J. Pilittere, Marcus Thames        Matt Blake   Reggie Willits
# 2019  P.J. Pilittere, Marcus Thames  Larry Rothschild   Reggie Willits
# 2018  P.J. Pilittere, Marcus Thames  Larry Rothschild   Reggie Willits
# 2017   Alan Cockrell, Marcus Thames  Larry Rothschild        Tony Pena
#
#      Third Base Coach Bullpen Coach
# Year
# 2021       Phil Nevin   Mike Harkey
# 2020       Phil Nevin   Mike Harkey
# 2019       Phil Nevin   Mike Harkey
# 2018       Phil Nevin   Mike Harkey
# 2017       Joe Espada   Mike Harkey

# %%
#make sure it's a df
print(type(ym))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#drop the unecessary columns
ym = ym.drop(columns=['Stats', 'Roster','Team Pages'])

# %%
len(ym)
# Out:
# 122

# %%
ym = ym.drop(index='Year')

# %%
len(ym)
# Out:
# 121

# %%
ym
# Out:
#        Field Manager     Bench Coach                  Hitting Coach  \
# Year
# 2021     Aaron Boone  Carlos Mendoza  P.J. Pilittere, Marcus Thames
# 2020     Aaron Boone  Carlos Mendoza  P.J. Pilittere, Marcus Thames
# 2019     Aaron Boone       Josh Bard  P.J. Pilittere, Marcus Thames
# 2018     Aaron Boone       Josh Bard  P.J. Pilittere, Marcus Thames
# 2017     Joe Girardi     Rob Thomson   Alan Cockrell, Marcus Thames
# ...              ...             ...                            ...
# 1905  Clark Griffith             NaN                            NaN
# 1904  Clark Griffith             NaN                            NaN
# 1903  Clark Griffith             NaN                            NaN
# 1902             NaN             NaN                            NaN
# 1901             NaN             NaN                            NaN
#
#         Pitching Coach First Base Coach Third Base Coach Bullpen Coach
# Year
# 2021        Matt Blake   Reggie Willits       Phil Nevin   Mike Harkey
# 2020        Matt Blake   Reggie Willits       Phil Nevin   Mike Harkey
# 2019  Larry Rothschild   Reggie Willits       Phil Nevin   Mike Harkey
# 2018  Larry Rothschild   Reggie Willits       Phil Nevin   Mike Harkey
# 2017  Larry Rothschild        Tony Pena       Joe Espada   Mike Harkey
# ...                ...              ...              ...           ...
# 1905               NaN              NaN              NaN           NaN
# 1904               NaN              NaN              NaN           NaN
# 1903               NaN              NaN              NaN           NaN
# 1902               NaN              NaN              NaN           NaN
# 1901               NaN              NaN              NaN           NaN
#
# [121 rows x 7 columns]

# %%
#drop any NA columns for manager
ym = ym[ym['Field Manager'].notna()]
len(ym)
# Out:
# 119

# %%
#identify managers fired mid-year (not their staff)
ym2 = ym.loc[ym['Field Manager'].str.contains(",", case=False)]
len(ym2) #15 guys
ym2.head()
# Out:
#                             Field Manager        Bench Coach  \
# Year
# 1990            Bucky Dent, Stump Merrill                NaN
# 1989             Bucky Dent, Dallas Green        Charlie Fox
# 1988           Billy Martin, Lou Piniella  George Mitterwald
# 1985             Yogi Berra, Billy Martin                NaN
# 1982  Clyde King, Bob Lemon, Gene Michael      Joe Altobelli
#
#                     Hitting Coach                  Pitching Coach  \
# Year
# 1990                Darrell Evans                    Bill Connors
# 1989  Frank Howard, Champ Summers                    Bill Connors
# 1988              Chris Chambliss       Clyde King, Stan Williams
# 1985                 Lou Piniella  Mark Connor, Bill Monbouquette
# 1982                Mickey Vernon                   Stan Williams
#
#                 First Base Coach             Third Base Coach  \
# Year
# 1990                Mike Ferraro  Buck Showalter , Joe Sparks
# 1989  Pat Corrales, Mike Ferraro      Lee Elia , Gene Michael
# 1988                Mike Ferraro   Clete Boyer , Gene Michael
# 1985               Stump Merrill                 Gene Michael
# 1982                  Yogi Berra                 Mike Ferraro
#
#                            Bullpen Coach
# Year
# 1990              Mark Connor, Gary Tuck
# 1989                        John Stearns
# 1988                        Jeff Torborg
# 1985  Dom Scala, Dom Scala, Jeff Torborg
# 1982             Dom Scala, Jeff Torborg

# %%
#remove the mid year guys
ym = ym.loc[~ym['Field Manager'].str.contains(",", case=False)]
len(ym)
# Out:
# 104

# %%
#split any remaining column 

ym[['Hitting Coach 1','Hitting Coach 2']] =ym['Hitting Coach'].str.split(',', expand=True)
ym[['Pitching Coach 1','Pitching Coach 2']] =ym['Pitching Coach'].str.split(',', expand=True)
#note the first and third base coaches don't need splitting because there is never a record with shared duties
#that's why it throws an error

# %%
ym.sample()
# Out:
#      Field Manager Bench Coach Hitting Coach    Pitching Coach  \
# Year
# 2014   Joe Girardi   Tony Pena    Kevin Long  Larry Rothschild
#
#      First Base Coach Third Base Coach Bullpen Coach Hitting Coach 1  \
# Year
# 2014    Mick Kelleher      Rob Thomson     Gary Tuck      Kevin Long
#
#      Hitting Coach 2  Pitching Coach 1 Pitching Coach 2
# Year
# 2014            None  Larry Rothschild             None

# %%
ym[['Bullpen Coach 1','Bullpen Coach 2','Bullpen Coach 3']] =ym['Bullpen Coach'].str.split(',', expand=True)

# %%
#ensure it's working
ym.sample()
# Out:
#       Field Manager   Bench Coach Hitting Coach Pitching Coach  \
# Year
# 1991  Stump Merrill  Mike Ferraro  Frank Howard    Mark Connor
#
#      First Base Coach Third Base Coach Bullpen Coach Hitting Coach 1  \
# Year
# 1991    Graig Nettles   Buck Showalter     Marc Hill    Frank Howard
#
#      Hitting Coach 2 Pitching Coach 1 Pitching Coach 2 Bullpen Coach 1  \
# Year
# 1991            None      Mark Connor             None       Marc Hill
#
#      Bullpen Coach 2 Bullpen Coach 3
# Year
# 1991            None            None

# %%
#make separate df for cleaned data, but create another one that drops initial HC PC BC columns (now we have that split out)
ym_old = ym
ym = ym.drop(columns=['Hitting Coach', 'Pitching Coach','Bullpen Coach'])

# %%
ym.sample()
# Out:
#       Field Manager Bench Coach First Base Coach  Third Base Coach  \
# Year
# 1951  Casey Stengel         NaN              NaN  Frankie Crosetti
#
#      Hitting Coach 1 Hitting Coach 2 Pitching Coach 1 Pitching Coach 2  \
# Year
# 1951             NaN             NaN              NaN              NaN
#
#      Bullpen Coach 1 Bullpen Coach 2 Bullpen Coach 3
# Year
# 1951             NaN             NaN             NaN

# %%
ym.tail()
# Out:
#        Field Manager Bench Coach First Base Coach Third Base Coach  \
# Year
# 1907  Clark Griffith         NaN              NaN              NaN
# 1906  Clark Griffith         NaN              NaN              NaN
# 1905  Clark Griffith         NaN              NaN              NaN
# 1904  Clark Griffith         NaN              NaN              NaN
# 1903  Clark Griffith         NaN              NaN              NaN
#
#      Hitting Coach 1 Hitting Coach 2 Pitching Coach 1 Pitching Coach 2  \
# Year
# 1907             NaN             NaN              NaN              NaN
# 1906             NaN             NaN              NaN              NaN
# 1905             NaN             NaN              NaN              NaN
# 1904             NaN             NaN              NaN              NaN
# 1903             NaN             NaN              NaN              NaN
#
#      Bullpen Coach 1 Bullpen Coach 2 Bullpen Coach 3
# Year
# 1907             NaN             NaN             NaN
# 1906             NaN             NaN             NaN
# 1905             NaN             NaN             NaN
# 1904             NaN             NaN             NaN
# 1903             NaN             NaN             NaN

# %%
#replace "none" with NA
ym = ym.fillna(value=np.nan)
ym.head()
# Out:
#      Field Manager     Bench Coach First Base Coach Third Base Coach  \
# Year
# 2021   Aaron Boone  Carlos Mendoza   Reggie Willits       Phil Nevin
# 2020   Aaron Boone  Carlos Mendoza   Reggie Willits       Phil Nevin
# 2019   Aaron Boone       Josh Bard   Reggie Willits       Phil Nevin
# 2018   Aaron Boone       Josh Bard   Reggie Willits       Phil Nevin
# 2017   Joe Girardi     Rob Thomson        Tony Pena       Joe Espada
#
#      Hitting Coach 1 Hitting Coach 2  Pitching Coach 1 Pitching Coach 2  \
# Year
# 2021  P.J. Pilittere   Marcus Thames        Matt Blake              NaN
# 2020  P.J. Pilittere   Marcus Thames        Matt Blake              NaN
# 2019  P.J. Pilittere   Marcus Thames  Larry Rothschild              NaN
# 2018  P.J. Pilittere   Marcus Thames  Larry Rothschild              NaN
# 2017   Alan Cockrell   Marcus Thames  Larry Rothschild              NaN
#
#      Bullpen Coach 1 Bullpen Coach 2 Bullpen Coach 3
# Year
# 2021     Mike Harkey             NaN             NaN
# 2020     Mike Harkey             NaN             NaN
# 2019     Mike Harkey             NaN             NaN
# 2018     Mike Harkey             NaN             NaN
# 2017     Mike Harkey             NaN             NaN

# %% [markdown]
# Testing it out. Remember, this is wrong but proof of concept to start

# %%
#YOUR DIRECTORY HERE
ym.to_csv(#YOUR DIRECTORY HERE,
         na_rep = "NA",
         index = False,
         header = False)

# %%
#YOUR DIRECTORY HERE
G=nx.read_adjlist(#YOUR DIRECTORY HERE,
             delimiter=",")

list(G.nodes()) #nodes method
#G.nodes() gives a nodeview object, which is like a dict, but not very useful
# Out:
# ['Aaron Boone',
#  'Carlos Mendoza',
#  'Reggie Willits',
#  'Phil Nevin',
#  'P.J. Pilittere',
#  ' Marcus Thames',
#  'Matt Blake',
#  'NA',
#  'Mike Harkey',
#  'Josh Bard',
#  'Larry Rothschild',
#  'Joe Girardi',
#  'Rob Thomson',
#  'Tony Pena',
#  'Joe Espada',
#  'Alan Cockrell',
#  ' Jeff Pentland',
#  'Gary Tuck',
#  'Mick Kelleher',
#  'Kevin Long',
#  'Dave Eiland',
#  'Bob Meacham',
#  ' Tommy Phelps',
#  'Joe Torre',
#  'Don Mattingly',
#  'Larry Bowa',
#  'Ron Guidry',
#  'Joe Kerrigan',
#  'Lee Mazzilli',
#  'Roy White',
#  'Luis Sojo',
#  'Mel Stottlemyre',
#  'Neil Allen',
#  'Willie Randolph',
#  'Rich Monteleone',
#  'Don Zimmer',
#  'Rick Down',
#  'Gary Denbo',
#  'Tony Cloninger',
#  'Chris Chambliss',
#  'Jose Cardenal',
#  'Buck Showalter',
#  'Brian Butterfield',
#  'Bill Connors',
#  ' Nardi Contreras',
#  'Clete Boyer',
#  'Ed Napoleon',
#  'Mark Connor',
#  'Russ Meyer',
#  'Frank Howard',
#  'Stump Merrill',
#  'Mike Ferraro',
#  'Graig Nettles',
#  'Marc Hill',
#  'Lou Piniella',
#  'Jay Ward',
#  'Jeff Torborg',
#  'Gene Michael',
#  'Joe Altobelli',
#  'Willie Horton',
#  ' Bill Monbouquette',
#  'Yogi Berra',
#  'Jerry McNertney',
#  ' Dom Scala',
#  ' Jeff Torborg',
#  'Billy Martin',
#  'Lee Walls',
#  'Art Fowler',
#  'Dom Scala',
#  'Dick Howser',
#  'Charlie Lau',
#  'Stan Williams',
#  'Jim Hegan',
#  'Elston Howard',
#  'Bobby Cox',
#  'Cloyd Boyer',
#  'Bob Lemon',
#  'Bill Virdon',
#  'Whitey Ford',
#  'Mel Wright',
#  'Ralph Houk',
#  'Jim Turner',
#  'Mickey Mantle',
#  'Frankie Crosetti',
#  'Loren Babe',
#  'Johnny Keane',
#  'Vern Benson',
#  'Cot Deal',
#  'Jim Gleeson',
#  'Wally Moses',
#  'Johnny Sain',
#  'Casey Stengel',
#  'Charlie Keller',
#  'Bucky Harris',
#  'Joe McCarthy',
#  'Bob Shawkey',
#  'Miller Huggins',
#  'Bill Donovan',
#  'Frank Chance',
#  'Harry Wolverton',
#  'Hal Chase',
#  'George Stallings',
#  'Clark Griffith']

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 103
# Number of edges: 147
# Average degree:   2.8544

# %%
layout = nx.spring_layout(G)
plt.figure(figsize=(12,12)) 
nx.draw(G,layout,with_labels=True)
plt.savefig("/Users/peterbarston/Documents/Outside School/Coding/Outside School Python/Blog Boi/Week of 9.27 - Python:Network Practice/ym_testpic.png")
plt.show()

# %% [markdown]
# Swapping columns

# %%
import numpy as np

# %%
ym_array = ym.to_numpy()

# %%
#test it worked1
ym.head()
# Out:
#      Field Manager     Bench Coach First Base Coach Third Base Coach  \
# Year
# 2021   Aaron Boone  Carlos Mendoza   Reggie Willits       Phil Nevin
# 2020   Aaron Boone  Carlos Mendoza   Reggie Willits       Phil Nevin
# 2019   Aaron Boone       Josh Bard   Reggie Willits       Phil Nevin
# 2018   Aaron Boone       Josh Bard   Reggie Willits       Phil Nevin
# 2017   Joe Girardi     Rob Thomson        Tony Pena       Joe Espada
#
#      Hitting Coach 1 Hitting Coach 2  Pitching Coach 1 Pitching Coach 2  \
# Year
# 2021  P.J. Pilittere   Marcus Thames        Matt Blake              NaN
# 2020  P.J. Pilittere   Marcus Thames        Matt Blake              NaN
# 2019  P.J. Pilittere   Marcus Thames  Larry Rothschild              NaN
# 2018  P.J. Pilittere   Marcus Thames  Larry Rothschild              NaN
# 2017   Alan Cockrell   Marcus Thames  Larry Rothschild              NaN
#
#      Bullpen Coach 1 Bullpen Coach 2 Bullpen Coach 3
# Year
# 2021     Mike Harkey             NaN             NaN
# 2020     Mike Harkey             NaN             NaN
# 2019     Mike Harkey             NaN             NaN
# 2018     Mike Harkey             NaN             NaN
# 2017     Mike Harkey             NaN             NaN

# %%
#test it worked2
print("Original array:")
print(ym_array)
# Out:
# Original array:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#make the first change:
bench_coach_array = np.copy(ym_array)
bench_coach_array[:,[0, 1]] = bench_coach_array[:,[1, 0]]
print("\nAfter swapping arrays:")
print(bench_coach_array)
# Out:
# After swapping arrays:
# [['Carlos Mendoza' 'Aaron Boone' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Carlos Mendoza' 'Aaron Boone' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Josh Bard' 'Aaron Boone' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  [nan 'Clark Griffith' nan ... nan nan nan]
#  [nan 'Clark Griffith' nan ... nan nan nan]
#  [nan 'Clark Griffith' nan ... nan nan nan]]

# %%
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %% [markdown]
# Iterate

# %%
#new array - 1b
first_base_array = np.copy(ym_array)
first_base_array[:,[0, 2]] = first_base_array[:,[2, 0]]
print("\nAfter swapping arrays:")
print(first_base_array)
# Out:
# After swapping arrays:
# [['Reggie Willits' 'Carlos Mendoza' 'Aaron Boone' ... 'Mike Harkey' nan
#   nan]
#  ['Reggie Willits' 'Carlos Mendoza' 'Aaron Boone' ... 'Mike Harkey' nan
#   nan]
#  ['Reggie Willits' 'Josh Bard' 'Aaron Boone' ... 'Mike Harkey' nan nan]
#  ...
#  [nan nan 'Clark Griffith' ... nan nan nan]
#  [nan nan 'Clark Griffith' ... nan nan nan]
#  [nan nan 'Clark Griffith' ... nan nan nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - 3b
third_base_array = np.copy(ym_array)
third_base_array[:,[0, 3]] = third_base_array[:,[3, 0]]
print("\nAfter swapping arrays:")
print(third_base_array)
# Out:
# After swapping arrays:
# [['Phil Nevin' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Phil Nevin' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Phil Nevin' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - hc1
hitting_coach_1_array = np.copy(ym_array)
hitting_coach_1_array[:,[0, 4]] = hitting_coach_1_array[:,[4, 0]]
print("\nAfter swapping arrays:")
print(hitting_coach_1_array)
# Out:
# After swapping arrays:
# [['P.J. Pilittere' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey'
#   nan nan]
#  ['P.J. Pilittere' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey'
#   nan nan]
#  ['P.J. Pilittere' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - hc2
hitting_coach_2_array = np.copy(ym_array)
hitting_coach_2_array[:,[0, 5]] = hitting_coach_2_array[:,[5, 0]]
print("\nAfter swapping arrays:")
print(hitting_coach_2_array)
# Out:
# After swapping arrays:
# [[' Marcus Thames' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey'
#   nan nan]
#  [' Marcus Thames' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey'
#   nan nan]
#  [' Marcus Thames' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - pc1
pitching_coach_1_array = np.copy(ym_array)
pitching_coach_1_array[:,[0, 6]] = pitching_coach_1_array[:,[6, 0]]
print("\nAfter swapping arrays:")
print(pitching_coach_1_array)
# Out:
# After swapping arrays:
# [['Matt Blake' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Matt Blake' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Larry Rothschild' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - pc2
pitching_coach_2_array = np.copy(ym_array)
pitching_coach_2_array[:,[0, 7]] = pitching_coach_2_array[:,[7, 0]]
print("\nAfter swapping arrays:")
print(pitching_coach_2_array)
# Out:
# After swapping arrays:
# [[nan 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  [nan 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  [nan 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - bc1
bullpen_coach_1_array = np.copy(ym_array)
bullpen_coach_1_array[:,[0, 8]] = bullpen_coach_1_array[:,[8, 0]]
print("\nAfter swapping arrays:")
print(bullpen_coach_1_array)
# Out:
# After swapping arrays:
# [['Mike Harkey' 'Carlos Mendoza' 'Reggie Willits' ... 'Aaron Boone' nan
#   nan]
#  ['Mike Harkey' 'Carlos Mendoza' 'Reggie Willits' ... 'Aaron Boone' nan
#   nan]
#  ['Mike Harkey' 'Josh Bard' 'Reggie Willits' ... 'Aaron Boone' nan nan]
#  ...
#  [nan nan nan ... 'Clark Griffith' nan nan]
#  [nan nan nan ... 'Clark Griffith' nan nan]
#  [nan nan nan ... 'Clark Griffith' nan nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - bc2
bullpen_coach_2_array = np.copy(ym_array)
bullpen_coach_2_array[:,[0, 9]] = bullpen_coach_2_array[:,[9, 0]]
print("\nAfter swapping arrays:")
print(bullpen_coach_2_array)
# Out:
# After swapping arrays:
# [[nan 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' 'Aaron Boone'
#   nan]
#  [nan 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' 'Aaron Boone'
#   nan]
#  [nan 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' 'Aaron Boone' nan]
#  ...
#  [nan nan nan ... nan 'Clark Griffith' nan]
#  [nan nan nan ... nan 'Clark Griffith' nan]
#  [nan nan nan ... nan 'Clark Griffith' nan]]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %%
#new array - bc3
bullpen_coach_3_array = np.copy(ym_array)
bullpen_coach_3_array[:,[0, 10]] = bullpen_coach_3_array[:,[10, 0]]
print("\nAfter swapping arrays:")
print(bullpen_coach_3_array)
# Out:
# After swapping arrays:
# [[nan 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   'Aaron Boone']
#  [nan 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   'Aaron Boone']
#  [nan 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan 'Aaron Boone']
#  ...
#  [nan nan nan ... nan nan 'Clark Griffith']
#  [nan nan nan ... nan nan 'Clark Griffith']
#  [nan nan nan ... nan nan 'Clark Griffith']]

# %%
#check old array
print(ym_array)
# Out:
# [['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Carlos Mendoza' 'Reggie Willits' ... 'Mike Harkey' nan
#   nan]
#  ['Aaron Boone' 'Josh Bard' 'Reggie Willits' ... 'Mike Harkey' nan nan]
#  ...
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]
#  ['Clark Griffith' nan nan ... nan nan nan]]

# %% [markdown]
# Ultimately we will make a giant adjancency list by concatenating the new arrays.  Don't forget to drop any rows with NaN in the first column

# %%
total_array = np.concatenate((ym_array,
 bench_coach_array,
 first_base_array,
 third_base_array,
 hitting_coach_1_array,
 hitting_coach_2_array,
 pitching_coach_1_array,
 pitching_coach_2_array,
 bullpen_coach_1_array,
 bullpen_coach_2_array,
 bullpen_coach_3_array),axis = 0)

# %%
#test it worked
len(total_array) - (len(ym_array)*11)
# Out:
# 0

# %%
#convert back to DF
total_df = pd.DataFrame(total_array,
                   columns = list(ym))
total_df.head()
# Out:
#   Field Manager     Bench Coach First Base Coach Third Base Coach  \
# 0   Aaron Boone  Carlos Mendoza   Reggie Willits       Phil Nevin
# 1   Aaron Boone  Carlos Mendoza   Reggie Willits       Phil Nevin
# 2   Aaron Boone       Josh Bard   Reggie Willits       Phil Nevin
# 3   Aaron Boone       Josh Bard   Reggie Willits       Phil Nevin
# 4   Joe Girardi     Rob Thomson        Tony Pena       Joe Espada
#
#   Hitting Coach 1 Hitting Coach 2  Pitching Coach 1 Pitching Coach 2  \
# 0  P.J. Pilittere   Marcus Thames        Matt Blake              NaN
# 1  P.J. Pilittere   Marcus Thames        Matt Blake              NaN
# 2  P.J. Pilittere   Marcus Thames  Larry Rothschild              NaN
# 3  P.J. Pilittere   Marcus Thames  Larry Rothschild              NaN
# 4   Alan Cockrell   Marcus Thames  Larry Rothschild              NaN
#
#   Bullpen Coach 1 Bullpen Coach 2 Bullpen Coach 3
# 0     Mike Harkey             NaN             NaN
# 1     Mike Harkey             NaN             NaN
# 2     Mike Harkey             NaN             NaN
# 3     Mike Harkey             NaN             NaN
# 4     Mike Harkey             NaN             NaN

# %%
#don't forget to remove the leading white space!
total_df = total_df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
total_df.head()

# %%
#test it worked
len(total_df)-(len(ym_array)*11)
# Out:
# 0

# %%
#see how many we should be dropping
#as a reminder
len(total_df)
# Out:
# 1144

# %%
total_df.isna().sum()
# Out:
# Field Manager        734
# Bench Coach          700
# First Base Coach     560
# Third Base Coach     390
# Hitting Coach 1      630
# Hitting Coach 2      970
# Pitching Coach 1     530
# Pitching Coach 2    1010
# Bullpen Coach 1      520
# Bullpen Coach 2     1000
# Bullpen Coach 3     1030
# dtype: int64

# %%
#so we should expect
len(total_df) - total_df['Field Manager'].isna().sum()
# Out:
# 410

# %%
#drop rows that start with NA
total_df = total_df[total_df['Field Manager'].notna()]

# %%
len(total_df)
# Out:
# 410

# %% [markdown]
# Let's convert to a graph

# %%
#YOUR DIRECTORY HERE
total_df.to_csv(#YOUR DIRECTORY HERE,
         na_rep = "NA",
        index = False,
         header = False)

# %%
#YOUR DIRECTORY HERE
G=nx.read_adjlist(#YOUR DIRECTORY HERE,
             delimiter=",")

list(G.nodes()) #nodes method
#G.nodes() gives a nodeview object, which is like a dict, but not very useful
# Out:
# ['Aaron Boone',
#  'Carlos Mendoza',
#  'Reggie Willits',
#  'Phil Nevin',
#  'P.J. Pilittere',
#  ' Marcus Thames',
#  'Matt Blake',
#  'NA',
#  'Mike Harkey',
#  'Josh Bard',
#  'Larry Rothschild',
#  'Joe Girardi',
#  'Rob Thomson',
#  'Tony Pena',
#  'Joe Espada',
#  'Alan Cockrell',
#  ' Jeff Pentland',
#  'Gary Tuck',
#  'Mick Kelleher',
#  'Kevin Long',
#  'Dave Eiland',
#  'Bob Meacham',
#  ' Tommy Phelps',
#  'Joe Torre',
#  'Don Mattingly',
#  'Larry Bowa',
#  'Ron Guidry',
#  'Joe Kerrigan',
#  'Lee Mazzilli',
#  'Roy White',
#  'Luis Sojo',
#  'Mel Stottlemyre',
#  'Neil Allen',
#  'Willie Randolph',
#  'Rich Monteleone',
#  'Don Zimmer',
#  'Rick Down',
#  'Gary Denbo',
#  'Tony Cloninger',
#  'Chris Chambliss',
#  'Jose Cardenal',
#  'Buck Showalter',
#  'Brian Butterfield',
#  'Bill Connors',
#  ' Nardi Contreras',
#  'Clete Boyer',
#  'Ed Napoleon',
#  'Mark Connor',
#  'Russ Meyer',
#  'Frank Howard',
#  'Stump Merrill',
#  'Mike Ferraro',
#  'Graig Nettles',
#  'Marc Hill',
#  'Lou Piniella',
#  'Jay Ward',
#  'Jeff Torborg',
#  'Gene Michael',
#  'Joe Altobelli',
#  'Willie Horton',
#  ' Bill Monbouquette',
#  'Yogi Berra',
#  'Jerry McNertney',
#  ' Dom Scala',
#  ' Jeff Torborg',
#  'Billy Martin',
#  'Lee Walls',
#  'Art Fowler',
#  'Dom Scala',
#  'Dick Howser',
#  'Charlie Lau',
#  'Stan Williams',
#  'Jim Hegan',
#  'Elston Howard',
#  'Bobby Cox',
#  'Cloyd Boyer',
#  'Bob Lemon',
#  'Bill Virdon',
#  'Whitey Ford',
#  'Mel Wright',
#  'Ralph Houk',
#  'Jim Turner',
#  'Mickey Mantle',
#  'Frankie Crosetti',
#  'Loren Babe',
#  'Johnny Keane',
#  'Vern Benson',
#  'Cot Deal',
#  'Jim Gleeson',
#  'Wally Moses',
#  'Johnny Sain',
#  'Casey Stengel',
#  'Charlie Keller',
#  'Bucky Harris',
#  'Joe McCarthy',
#  'Bob Shawkey',
#  'Miller Huggins',
#  'Bill Donovan',
#  'Frank Chance',
#  'Harry Wolverton',
#  'Hal Chase',
#  'George Stallings',
#  'Clark Griffith',
#  'Marcus Thames',
#  'Jeff Pentland',
#  'Tommy Phelps',
#  'Bill Monbouquette',
#  'Nardi Contreras']

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 108
# Number of edges: 627
# Average degree:  11.6111

# %%
layout = nx.spring_layout(G)
plt.figure(figsize=(12,12)) 
nx.draw(G,layout,with_labels=True)
plt.savefig("/Users/peterbarston/Documents/Outside School/Coding/Outside School Python/Blog Boi/Week of 9.27 - Python:Network Practice/ym_testpic2.png")
plt.show()

# %% [markdown]
# And Let's Get rid of that annoying NA guy

# %%
#remove the incorrect NA node
G.remove_node("NA")

# %%
layout = nx.spring_layout(G)
plt.figure(figsize=(12,12)) 
nx.draw(G,layout,with_labels=True)
plt.savefig("/Users/peterbarston/Documents/Outside School/Coding/Outside School Python/Blog Boi/Week of 9.27 - Python:Network Practice/ym_bestpic.png")
plt.show()

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 107
# Number of edges: 527
# Average degree:   9.8505

# %%
[len(c) for c in sorted(nx.connected_components(G), key=len, reverse=True)]
# Out:
# [98, 1, 1, 1, 1, 1, 1, 1, 1, 1]

# %% [markdown]
# Build the Random Graph

# %%
node_length = len(G.nodes())
node_length
# Out:
# 100

# %%
#get average degree
degrees = [val for (node, val) in G.degree()]
sum(degrees)
# Out:
# 916

# %%
avg_degree = sum(degrees) / node_length
avg_degree
# Out:
# 9.16

# %%
#creating p
p = avg_degree / node_length
p
# Out:
# 0.0916

# %%
#creating a comparable random graph
#n = 100
#p = average degree / number of nodes
g_random = nx.erdos_renyi_graph(node_length,p,seed = 7)

# %%
print(nx.info(g_random))
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 458
# Average degree:   9.1600

# %% [markdown]
# This week: following along here:https://networkx.org/documentation/stable/auto_examples/drawing/plot_degree.html?highlight=degree%20graph

# %% [markdown]
# For Yankees:

# %%
#for Yankees
degree_sequence = sorted([d for n, d in G.degree()], reverse=True) 
dmax = max(degree_sequence) 

fig = plt.figure("Degree of Yankees Graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :]) #first 3 rows, all columns display of this grid we created that is 9 x 9 (0 counts)
Gcc = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0]) #take just the connected components
#and grab the biggest one, then plot it
pos = nx.spring_layout(Gcc, seed=10396953)
nx.draw_networkx_nodes(Gcc, pos, ax=ax0, node_size=20)
nx.draw_networkx_edges(Gcc, pos, ax=ax0, alpha=0.4)
ax0.set_title("Graph of Yankees Connected components ")
ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2]) #last 6 rows, all columns up to 2 in this grid
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Yankees Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:]) #last 6 rows, all columns 2 and beyond in this grid
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Yankees Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

fig.tight_layout()
plt.show()

# %%
#proof of concept, this is just all connected components, sorting them by length, then the 0 says to grab the biggest one
Gcc = G.subgraph(sorted(nx.connected_components(G), key=len, reverse=True)[0])
print(nx.info(Gcc))
# Out:
# Name:
# Type: Graph
# Number of nodes: 91
# Number of edges: 458
# Average degree:  10.0659

# %% [markdown]
# For Random:

# %%
print(nx.info(g_random))
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 458
# Average degree:   9.1600

# %%
#for Random
degree_sequence = sorted([d for n, d in g_random.degree()], reverse=True) 
dmax = max(degree_sequence) 

fig = plt.figure("Degree of Yankees Graph", figsize=(8, 8))
# Create a gridspec for adding subplots of different sizes
axgrid = fig.add_gridspec(5, 4)

ax0 = fig.add_subplot(axgrid[0:3, :]) #first 3 rows, all columns display of this grid we created that is 9 x 9 (0 counts)
Gcc = g_random.subgraph(sorted(nx.connected_components(g_random), key=len, reverse=True)[0]) #take just the connected components
#and grab the biggest one, then plot it
pos = nx.spring_layout(Gcc, seed=7)
nx.draw_networkx_nodes(Gcc, pos, ax=ax0, node_size=20)
nx.draw_networkx_edges(Gcc, pos, ax=ax0, alpha=0.4)
ax0.set_title("Graph of Random Connected component")
ax0.set_axis_off()

ax1 = fig.add_subplot(axgrid[3:, :2]) #last 6 rows, all columns up to 2 in this grid
ax1.plot(degree_sequence, "b-", marker="o")
ax1.set_title("Random Degree Rank Plot")
ax1.set_ylabel("Degree")
ax1.set_xlabel("Rank")

ax2 = fig.add_subplot(axgrid[3:, 2:]) #last 6 rows, all columns 2 and beyond in this grid
ax2.bar(*np.unique(degree_sequence, return_counts=True))
ax2.set_title("Random Degree histogram")
ax2.set_xlabel("Degree")
ax2.set_ylabel("# of Nodes")

fig.tight_layout()
plt.show()

# %%
Gcc = g_random.subgraph(sorted(nx.connected_components(g_random), key=len, reverse=True)[0])
print(nx.info(Gcc))
# Out:
# Name:
# Type: Graph
# Number of nodes: 100
# Number of edges: 458
# Average degree:   9.1600
